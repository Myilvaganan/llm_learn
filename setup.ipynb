# %%
pip install --retries 5 --timeout 15 --no-cache-dir --force-reinstall -r requirements.txt
# Out:
# Collecting python-dotenv (from -r requirements.txt (line 1))
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting openai (from -r requirements.txt (line 2))
#   Downloading openai-2.16.0-py3-none-any.whl.metadata (29 kB)
# Collecting scraper (from -r requirements.txt (line 3))
#   Downloading scraper-0.1.0.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anyio<5,>=3.5.0 (from openai->-r requirements.txt (line 2))
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from openai->-r requirements.txt (line 2))
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai->-r requirements.txt (line 2))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai->-r requirements.txt (line 2))
#   Downloading jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai->-r requirements.txt (line 2))
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openai->-r requirements.txt (line 2))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai->-r requirements.txt (line 2))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<5,>=4.11 (from openai->-r requirements.txt (line 2))
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting lxml>=3.0.1 (from scraper->-r requirements.txt (line 3))
#   Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 2))
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 2))
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 2))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 2))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 2))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 2))
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 2))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading openai-2.16.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 255.3 kB/s eta 0:00:0000:0100:02
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (319 kB)
# Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 258.1 kB/s eta 0:00:00a 0:00:01
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 180.1 kB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Building wheels for collected packages: scraper
#   Building wheel for scraper (pyproject.toml) ... done
#   Created wheel for scraper: filename=scraper-0.1.0-py3-none-any.whl size=3541 sha256=34f53a09a628f370e82d6e4a47aa0f755d82d11ec2ad3051e0acad3786d3b484
#   Stored in directory: /private/var/folders/0k/99rlf26j7hd_5lmcj6f66rc00000gp/T/pip-ephem-wheel-cache-_5343rje/wheels/1c/0b/5b/73e1b96a17d86b497ec51e061ce25285e21af2ae0fda386c72
# Successfully built scraper
# Installing collected packages: typing-extensions, tqdm, sniffio, python-dotenv, lxml, jiter, idna, h11, distro, certifi, annotated-types, typing-inspection, scraper, pydantic-core, httpcore, anyio, pydantic, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 certifi-2026.1.4 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.12.0 lxml-6.0.2 openai-2.16.0 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.1 scraper-0.1.0 sniffio-1.3.1 tqdm-4.67.1 typing-extensions-4.15.0 typing-inspection-0.4.2
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.13/site-packages (25.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
